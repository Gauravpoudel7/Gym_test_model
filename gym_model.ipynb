# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("gym_members_exercise_tracking.csv")

# %%
df
# Out:
#      Age  Gender  ...  Experience_Level    BMI
# 0     56    Male  ...                 3  30.20
# 1     46  Female  ...                 2  32.00
# 2     32  Female  ...                 2  24.71
# 3     25    Male  ...                 1  18.41
# 4     38    Male  ...                 1  14.39
# ..   ...     ...  ...               ...    ...
# 968   24    Male  ...                 3  28.77
# 969   25    Male  ...                 1  25.69
# 970   59  Female  ...                 3  19.50
# 971   32    Male  ...                 2  37.74
# 972   46    Male  ...                 1  33.38
#
# [973 rows x 15 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 973 entries, 0 to 972
# Data columns (total 15 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Age                            973 non-null    int64
#  1   Gender                         973 non-null    str
#  2   Weight (kg)                    973 non-null    float64
#  3   Height (m)                     973 non-null    float64
#  4   Max_BPM                        973 non-null    int64
#  5   Avg_BPM                        973 non-null    int64
#  6   Resting_BPM                    973 non-null    int64
#  7   Session_Duration (hours)       973 non-null    float64
#  8   Calories_Burned                973 non-null    float64
#  9   Workout_Type                   973 non-null    str
#  10  Fat_Percentage                 973 non-null    float64
#  11  Water_Intake (liters)          973 non-null    float64
#  12  Workout_Frequency (days/week)  973 non-null    int64
#  13  Experience_Level               973 non-null    int64
#  14  BMI                            973 non-null    float64
# dtypes: float64(7), int64(6), str(2)
# memory usage: 124.2 KB

# %%
df.describe()
# Out:
#               Age  Weight (kg)  ...  Experience_Level         BMI
# count  973.000000   973.000000  ...        973.000000  973.000000
# mean    38.683453    73.854676  ...          1.809866   24.912127
# std     12.180928    21.207500  ...          0.739693    6.660879
# min     18.000000    40.000000  ...          1.000000   12.320000
# 25%     28.000000    58.100000  ...          1.000000   20.110000
# 50%     40.000000    70.000000  ...          2.000000   24.160000
# 75%     49.000000    86.000000  ...          2.000000   28.560000
# max     59.000000   129.900000  ...          3.000000   49.840000
#
# [8 rows x 13 columns]

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Weight (kg)', 'Height (m)', 'Max_BPM', 'Avg_BPM',
#        'Resting_BPM', 'Session_Duration (hours)', 'Calories_Burned',
#        'Workout_Type', 'Fat_Percentage', 'Water_Intake (liters)',
#        'Workout_Frequency (days/week)', 'Experience_Level', 'BMI'],
#       dtype='str')

# %%
numeric_cols = ['Age', 'Weight (kg)', 'Height (m)', 'Max_BPM', 'Avg_BPM',
       'Resting_BPM', 'Session_Duration (hours)', 'Calories_Burned',
       'Fat_Percentage', 'Water_Intake (liters)',
       'Workout_Frequency (days/week)', 'Experience_Level', 'BMI']
for col in numeric_cols:
    plt.figure(figsize=(6,4))
    sns.histplot(df[col],kde=True,bins=20)

# %%
sns.countplot(df['Gender'])
# Out:
# <Axes: xlabel='count', ylabel='Gender'>

# %%
sns.countplot(df['Workout_Type'])
# Out:
# <Axes: xlabel='count', ylabel='Workout_Type'>

# %%
for col in numeric_cols:
    plt.figure(figsize=(6,4))
    sns.boxplot(x = df[col])

# %%
plt.figure(figsize=(8,5))
sns.heatmap(df.corr(numeric_only=True))
# Out:
# <Axes: >

# %%
 #forcals
df["Calories_Burned"].plot(kind="hist",bins=50)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df["Calories_Burned"].plot(kind="kde")
# Out:
# <Axes: ylabel='Density'>

# %%
df['Calories_Burned'].plot(kind='box')
# Out:
# <Axes: >

# %%
df[df['Calories_Burned']>1600].describe()
# Out:
#              Age  Weight (kg)  ...  Experience_Level        BMI
# count  10.000000    10.000000  ...              10.0  10.000000
# mean   29.700000    83.920000  ...               3.0  28.200000
# std     8.692909     8.805655  ...               0.0   5.238725
# min    19.000000    60.100000  ...               3.0  18.760000
# 25%    24.250000    83.350000  ...               3.0  24.775000
# 50%    26.500000    86.700000  ...               3.0  30.315000
# 75%    35.000000    88.375000  ...               3.0  32.175000
# max    47.000000    89.800000  ...               3.0  33.720000
#
# [8 rows x 13 columns]

# %%
df['Calories_Burned'].skew()
# Out:
# np.float64(0.2783210950013363)

# %%
target = 'Calories_Burned'

# T ranking of which numbers affect calories the most
plt.figure(figsize=(10, 8))
correlation = df.corr(numeric_only=True)[target].sort_values(ascending=False)
sns.barplot(x=correlation.values, y=correlation.index, palette='RdBu')
plt.title(f'Correlation of Numerical Features with {target}')
plt.show()

#  loop through all columns to see their direct impact on Calories
cols_to_plot = [col for col in df.columns if col != target]

for col in cols_to_plot:
    plt.figure(figsize=(10, 5))
    
    # the column is numeric, using a Scatter Plot with a Regression Line
    if df[col].dtype in ['float64', 'int64']:
        sns.regplot(data=df, x=col, y=target, scatter_kws={'alpha':0.3}, line_kws={'color':'red'})
        plt.title(f'Relationship: {col} vs {target}')
        
    #  the column is categorical/object, using Box Plot
    else:
        sns.boxplot(data=df, x=col, y=target, palette='Set2')
        plt.xticks(rotation=45)
        plt.title(f'Impact of {col} on {target}')
    
    plt.tight_layout()
    plt.show()
# Out:
# C:\Users\Alpha1\AppData\Local\Temp\ipykernel_18448\1801238252.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=correlation.values, y=correlation.index, palette='RdBu')
# C:\Users\Alpha1\AppData\Local\Temp\ipykernel_18448\1801238252.py:23: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x=col, y=target, palette='Set2')
# C:\Users\Alpha1\AppData\Local\Temp\ipykernel_18448\1801238252.py:23: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x=col, y=target, palette='Set2')

# %%
from sklearn.model_selection import train_test_split
df.describe()
# Out:
#               Age  Weight (kg)  ...  Experience_Level         BMI
# count  973.000000   973.000000  ...        973.000000  973.000000
# mean    38.683453    73.854676  ...          1.809866   24.912127
# std     12.180928    21.207500  ...          0.739693    6.660879
# min     18.000000    40.000000  ...          1.000000   12.320000
# 25%     28.000000    58.100000  ...          1.000000   20.110000
# 50%     40.000000    70.000000  ...          2.000000   24.160000
# 75%     49.000000    86.000000  ...          2.000000   28.560000
# max     59.000000   129.900000  ...          3.000000   49.840000
#
# [8 rows x 13 columns]

# %%
# Create a new df with just 4 columns
new_df = df[['Calories_Burned','Experience_Level','Session_Duration (hours)','Fat_Percentage','Workout_Type']]

print(new_df.head())
# Out:
#    Calories_Burned  Experience_Level  ...  Fat_Percentage  Workout_Type
# 0           1313.0                 3  ...            12.6          Yoga
# 1            883.0                 2  ...            33.9          HIIT
# 2            677.0                 2  ...            33.4        Cardio
# 3            532.0                 1  ...            28.8      Strength
# 4            556.0                 1  ...            29.2      Strength
#
# [5 rows x 5 columns]

# %%
new_df['Workout_Type'] = new_df['Workout_Type'].map({
    'Yoga': 0,
    'HIIT': 1,
    'Strength':2,
    'Cardio':3
})

# %%
x=new_df.drop('Calories_Burned',axis=1)
y=new_df['Calories_Burned']

# %%
X_train, X_test, y_train, y_test = train_test_split(
x, y, test_size=0.25, random_state=42)

# %%
new_df.describe()
# Out:
#        Calories_Burned  Experience_Level  ...  Fat_Percentage  Workout_Type
# count       973.000000        973.000000  ...      973.000000    973.000000
# mean        905.422405          1.809866  ...       24.976773      1.543679
# std         272.641516          0.739693  ...        6.259419      1.124637
# min         303.000000          1.000000  ...       10.000000      0.000000
# 25%         720.000000          1.000000  ...       21.300000      1.000000
# 50%         893.000000          2.000000  ...       26.200000      2.000000
# 75%        1076.000000          2.000000  ...       29.300000      3.000000
# max        1783.000000          3.000000  ...       35.000000      3.000000
#
# [8 rows x 5 columns]

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train=scaler.fit_transform(X_train)
X_test = scaler.fit_transform(X_test)

# %%
new_df.head
# Out:
# <bound method NDFrame.head of      Calories_Burned  Experience_Level  ...  Fat_Percentage  Workout_Type
# 0             1313.0                 3  ...            12.6             0
# 1              883.0                 2  ...            33.9             1
# 2              677.0                 2  ...            33.4             3
# 3              532.0                 1  ...            28.8             2
# 4              556.0                 1  ...            29.2             2
# ..               ...               ...  ...             ...           ...
# 968           1364.0                 3  ...            10.0             2
# 969           1260.0                 1  ...            25.0             2
# 970            929.0                 3  ...            18.8             3
# 971            883.0                 2  ...            28.2             1
# 972            542.0                 1  ...            28.8             2
#
# [973 rows x 5 columns]>

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import r2_score

# %%
r2 = r2_score(y_test,y_pred)
r2
n=X_test.shape[0]
p = X_test.shape[1]
adjusted_r2=1-((1-r2)*(n-1)/(n-p-1))
adjusted_r2
# Out:
# 0.8291856549567992

# %%
import joblib

joblib.dump(model, "model.pkl")
# Out:
# ['model.pkl']

# %%
import seaborn as sns

sns.scatterplot(
    x=df["Session_Duration (hours)"],
    y=df["Calories_Burned"]
)
# Out:
# <Axes: xlabel='Session_Duration (hours)', ylabel='Calories_Burned'>

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Weight (kg)', 'Height (m)', 'Max_BPM', 'Avg_BPM',
#        'Resting_BPM', 'Session_Duration (hours)', 'Calories_Burned',
#        'Workout_Type', 'Fat_Percentage', 'Water_Intake (liters)',
#        'Workout_Frequency (days/week)', 'Experience_Level', 'BMI'],
#       dtype='str')

# %%
print(df[['Experience_Level', 'Calories_Burned']].groupby('Experience_Level').mean())
# Out:
#                   Calories_Burned
# Experience_Level
# 1                      726.375000
# 2                      901.918719
# 3                     1265.340314

# %%
new_df
# Out:
#      Calories_Burned  Experience_Level  Session_Duration (hours)  \
# 0             1313.0                 3                      1.69
# 1              883.0                 2                      1.30
# 2              677.0                 2                      1.11
# 3              532.0                 1                      0.59
# 4              556.0                 1                      0.64
# ..               ...               ...                       ...
# 968           1364.0                 3                      1.57
# 969           1260.0                 1                      1.38
# 970            929.0                 3                      1.72
# 971            883.0                 2                      1.10
# 972            542.0                 1                      0.75
#
#      Fat_Percentage  Workout_Type
# 0              12.6             0
# 1              33.9             1
# 2              33.4             3
# 3              28.8             2
# 4              29.2             2
# ..              ...           ...
# 968            10.0             2
# 969            25.0             2
# 970            18.8             3
# 971            28.2             1
# 972            28.8             2
#
# [973 rows x 5 columns]

# %%
new
